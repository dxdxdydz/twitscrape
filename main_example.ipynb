# %%
from twitscrape import twitscrape
import pandas as pd

# %%
Dict=twitscrape('orange')
# Out:
# []
# ------------------------------------------
# 9
# **********************************
# ...

# %%
pd.DataFrame(Dict)
# Out:
#                 user                                              tweet
# 0     /cding98526405  Very rear im a GTO fan to say the the least an...
# 1        /HIJ4DELUNA    rex orange county is so cute i love him so much
# 2       /chrlttsluvr                                         ako meron
# 3      /solangelobot  Will offered me a seat next to him, then passe...
# 4      /Dealsbuyers1  Walk-A-Long Puppy Wooden Pull Toy by Hape | Aw...
# ..               ...                                                ...
# 509     /dr_o_slayyy  …ya know you aren’t wrong…\n\nPinnacle whipped...
# 510   /smithspilled1  banana mango ginger whole milk orange pinapple...
# 511  /jennyybarron24  I need to quit playing with this orange/brown ...
# 512  /bluesidehobii_  the killer with that blue and orange heart is ...
# 513    /VermontAlert  Event Notification: Orange County http://dlvr....
#
# [514 rows x 2 columns]

# %%
Dict2=twitscrape('strawberry',includes=['chocolate'],n_tweets=1000)
# Out:
# []
# ------------------------------------------
# 9
# **********************************
# ...

# %%
pd.DataFrame(Dict2)
# Out:
#                   user                                              tweet
# 0        /FOUR_VICTIMS  J : well -\n\nJ : I baked like - six i think -...
# 1      /loghan1manzana               Qué prefieres frío o calor? Yo #Frio
# 2           /Jassinova  These were fun to make! Thanks @iam_SGreen for...
# 3     /TimCald07832410  The strawberry glazed with fruity  pebbles sou...
# 4          /terranceb4  Chocolate covered strawberries, sister. Two bi...
# ...                ...                                                ...
# 1009   /prxncesxpeach_            strawberry\npineapple\nbanana chocolate
# 1010   /prxncesxpeach_  strawberry\npineapple\nbanana chocolate (woi n...
# 1011   /prxncesxpeach_  strawberry\npineapple\nmix fruits\nbanana choc...
# 1012      /DorcasDynax  Chocolate >> Red velvet >> Vanilla >> Strawberry.
# 1013   /prxncesxpeach_            strawberry\npineapple\nbanana chocolate
#
# [1014 rows x 2 columns]
